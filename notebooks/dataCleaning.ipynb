# %%
import pandas as pd
import numpy as np

# %%
files = [
    "../data/USvideos.csv",
    "../data/INvideos.csv",
    "../data/GBvideos.csv"
]

dfs = [pd.read_csv(f) for f in files]
df = pd.concat(dfs, ignore_index=True)

df.shape
# Out:
# (117217, 16)

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# Fill missing values
df["description"] = df["description"].fillna("")
df["tags"] = df["tags"].fillna("")

# Convert publish_time to datetime
df["publish_time"] = pd.to_datetime(df["publish_time"], errors="coerce")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 106687 entries, 0 to 117216
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   video_id                106687 non-null  object
#  1   trending_date           106687 non-null  object
#  2   title                   106687 non-null  object
#  3   channel_title           106687 non-null  object
#  4   category_id             106687 non-null  int64
#  5   publish_time            106687 non-null  datetime64[ns, UTC]
#  6   tags                    106687 non-null  object
#  7   views                   106687 non-null  int64
#  8   likes                   106687 non-null  int64
#  9   dislikes                106687 non-null  int64
#  10  comment_count           106687 non-null  int64
#  11  thumbnail_link          106687 non-null  object
#  12  comments_disabled       106687 non-null  bool
#  13  ratings_disabled        106687 non-null  bool
#  14  video_error_or_removed  106687 non-null  bool
#  15  description             106687 non-null  object
# dtypes: bool(3), datetime64[ns, UTC](1), int64(5), object(7)
# memory usage: 11.7+ MB

# %%
df.to_csv("../data/combined_youtube.csv", index=False)

# %%
df.shape
# Out:
# (106687, 16)
